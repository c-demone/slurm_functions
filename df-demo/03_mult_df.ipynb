# %% [markdown]
# ### Initialize the Dask Dashboard Client
#
# Sets up a local cluster that handles the computations. It provides the details of the computation.

# %%
from dask.distributed import Client, progress
client = Client(n_workers=4, threads_per_worker=2, memory_limit='8GB')
client
# Out:
# <Client: 'tcp://127.0.0.1:45527' processes=4 threads=8, memory=29.80 GiB>

# %% [markdown]
# ### Reading multiple sources of data into multiple dataframes
#
# Reads three csv files into their own dataframes using the read_csv() function.

# %%
import dask
import dask.dataframe as dd
from dask.diagnostics import ProgressBar

# dataframe for covid cases daily count by country on 01/01/2021
df = dd.read_csv('data/010121.csv', dtype={'Active':'float64'}) # dtypes specified to read csv properly
df2 = dd.read_csv('data/020121.csv', dtype={'Active':'float64'})
df3 = dd.read_csv('data/030121.csv', dtype={'Active':'float64'})

# %% [markdown]
# ### Beginning of the Dataframes
#
# The head() function displays the beginning of the dataframe.

# %%
df.head()
# Out:
#   Province_State Country_Region      Last_Update       Lat      Long_  \
# 0            NaN    Afghanistan  02/01/2021 5:22  33.93911  67.709953
# 1            NaN        Albania  02/01/2021 5:22  41.15330  20.168300
# 2            NaN        Algeria  02/01/2021 5:22  28.03390   1.659600
# 3            NaN        Andorra  02/01/2021 5:22  42.50630   1.521800
# 4            NaN         Angola  02/01/2021 5:22 -11.20270  17.873900
#
#    Confirmed  Deaths  Recovered   Active Combined_Key  Incident_Rate  \
# 0      51526    2191      41727      0.0  Afghanistan       0.000000
# 1      58316    1181      33634  23501.0      Albania    2026.409062
# 2      99897    2762      67395  29740.0      Algeria     227.809861
# 3       8117      84       7463    570.0      Andorra   10505.403480
# 4      17568     405      11146   6017.0       Angola      53.452981
#
#    Case_Fatality_Ratio
# 0             4.252222
# 1             2.025173
# 2             2.764848
# 3             1.034865
# 4             2.305328

# %%
df2.head()
# Out:
#   Province_State Country_Region      Last_Update       Lat      Long_  \
# 0            NaN    Afghanistan  02/02/2021 5:22  33.93911  67.709953
# 1            NaN        Albania  02/02/2021 5:22  41.15330  20.168300
# 2            NaN        Algeria  02/02/2021 5:22  28.03390   1.659600
# 3            NaN        Andorra  02/02/2021 5:22  42.50630   1.521800
# 4            NaN         Angola  02/02/2021 5:22 -11.20270  17.873900
#
#    Confirmed  Deaths  Recovered   Active Combined_Key  Incident_Rate  \
# 0      55059    2404      47723   4932.0  Afghanistan     141.436801
# 1      78992    1393      47922  29677.0      Albania    2744.874557
# 2     107578    2894      73530  31154.0      Algeria     245.325978
# 3       9972     101       9206    665.0      Andorra   12906.231800
# 4      19829     466      18180   1183.0       Angola      60.332375
#
#    Case_Fatality_Ratio
# 0             4.366225
# 1             1.763470
# 2             2.690141
# 3             1.012836
# 4             2.350093

# %%
df3.head()
# Out:
#   Province_State Country_Region      Last_Update       Lat      Long_  \
# 0            NaN    Afghanistan  02/03/2021 5:23  33.93911  67.709953
# 1            NaN        Albania  02/03/2021 5:23  41.15330  20.168300
# 2            NaN        Algeria  02/03/2021 5:23  28.03390   1.659600
# 3            NaN        Andorra  02/03/2021 5:23  42.50630   1.521800
# 4            NaN         Angola  02/03/2021 5:23 -11.20270  17.873900
#
#    Confirmed  Deaths  Recovered   Active Combined_Key  Incident_Rate  \
# 0      55733    2444      49344   3945.0  Afghanistan     143.168187
# 1     107931    1816      70413  35702.0      Albania    3750.469108
# 2     113255    2987      78234  32034.0      Algeria     258.272078
# 3      10889     110      10475    304.0      Andorra   14093.056360
# 4      20854     508      19400    946.0       Angola      63.451074
#
#    Case_Fatality_Ratio
# 0             4.385194
# 1             1.682556
# 2             2.637411
# 3             1.010194
# 4             2.435984

# %%
# %%time

# Calculating the mean
print("Mean of confirmed global COVID-19 cases reported 01/01/2021:  " + str(df.Confirmed.mean().compute()))
print("Mean of reported global COVID-19 deaths reported 02/01/2021:  " + str(df2.Deaths.mean().compute()))
print("Mean of confirmed active global COVID-19 cases reported 03/01/2021:  " + str(df3.Active.mean().compute()))
# Out:
# Mean of confirmed global COVID-19 cases reported 01/01/2021:  21119.139307228917
# Mean of reported global COVID-19 deaths reported 02/01/2021:  579.2197140707299
# Mean of confirmed active global COVID-19 cases reported 03/01/2021:  11862.095859473024
# CPU times: user 60.5 ms, sys: 4.96 ms, total: 65.4 ms
# Wall time: 187 ms

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:45527' processes=4 threads=8, memory=29.80 GiB>

# %% [markdown]
# ### Merging the data
#
# Using the merge() function to merge all of the dataframes into one. Below you can see you can merge multiple dataframes by separating it with a period and calling the merge() function however many times necessary.

# %%
# %%time

result = df.merge(df2).merge(df3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# NameError: name 'df' is not defined

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:45527' processes=4 threads=8, memory=29.80 GiB>

# %%
result.head()
# Out:
#      Province_State Country_Region       Last_Update  Lat  Long_  Confirmed  \
# 0  Diamond Princess         Canada  21/12/2020 13:27  NaN    NaN          0
# 1    Grand Princess         Canada  21/12/2020 13:27  NaN    NaN         13
# 2           Alabama             US  21/12/2020 13:27  NaN    NaN          0
# 3           Alabama             US  21/12/2020 13:27  NaN    NaN          0
# 4  Diamond Princess             US   04/08/2020 2:27  NaN    NaN         49
#
#    Deaths  Recovered  Active              Combined_Key  Incident_Rate  \
# 0       1          0     NaN  Diamond Princess, Canada            NaN
# 1       0         13     0.0    Grand Princess, Canada            NaN
# 2       0          0     0.0    Out of AL, Alabama, US            NaN
# 3       0          0     0.0   Unassigned, Alabama, US            NaN
# 4       0          0    49.0      Diamond Princess, US            NaN
#
#    Case_Fatality_Ratio
# 0                  NaN
# 1                  0.0
# 2                  NaN
# 3                  NaN
# 4                  0.0

# %% [markdown]
# The total sum for each column is calculated with the sum() function and dataframe is displayed based on columns specified in the groupby() function.

# %%
# %%time
result.groupby(['Province_State', 'Country_Region']).sum().reset_index().compute()
# Out:
# CPU times: user 44.5 ms, sys: 119 µs, total: 44.7 ms
# Wall time: 122 ms
#      Province_State Country_Region  Lat  Long_  Confirmed  Deaths  Recovered  \
# 0           Alabama             US  0.0    0.0          0       0          0
# 1  Diamond Princess         Canada  0.0    0.0          0       1          0
# 2  Diamond Princess             US  0.0    0.0         49       0          0
# 3    Grand Princess         Canada  0.0    0.0         13       0         13
# 4    Grand Princess             US  0.0    0.0        103       3          0
# 5            Hawaii             US  0.0    0.0          0       0          0
# 6             Maine             US  0.0    0.0          0       0          0
# 7           Montana             US  0.0    0.0          0       0          0
# 8          Virginia             US  0.0    0.0          0       0          0
#
#    Active  Incident_Rate  Case_Fatality_Ratio
# 0     0.0            0.0             0.000000
# 1     0.0            0.0             0.000000
# 2    49.0            0.0             0.000000
# 3     0.0            0.0             0.000000
# 4   100.0            0.0             2.912621
# 5     0.0            0.0             0.000000
# 6     0.0            0.0             0.000000
# 7     0.0            0.0             0.000000
# 8     0.0            0.0             0.000000

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:45527' processes=4 threads=8, memory=29.80 GiB>
